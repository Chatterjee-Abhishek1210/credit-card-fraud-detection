# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # load dataset

# %%
df = pd.read_csv("creditcard.csv")

# %% [markdown]
# # Basic info

# %%
print(df.info())
display(df.head())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# # Check for missing values

# %%
print("\nMissing values:\n", df.isnull().sum().sum())
# Out:
# Missing values:
#  0

# %% [markdown]
# # Class distribution

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Class', data=df)
plt.title('Class Distribution (0 = Legit, 1 = Fraud)')
plt.show()
print("\nClass distribution:\n", df['Class'].value_counts())
# Out:
# Class distribution:
#  Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# # Amount distribution by class

# %%
plt.figure(figsize=(10,4))
sns.boxplot(x='Class', y='Amount', data=df)
plt.title('Transaction Amount by Class')
plt.show()

# %% [markdown]
# # Correlation matrix

# %%
plt.figure(figsize=(12,8))
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm_r', linewidths=0.5)
plt.title('Feature Correlation Matrix')
plt.show()

# %% [markdown]
# # Time vs Amount plot (sampled for speed)

# %%
sample_df = df.sample(n=10000, random_state=1)
plt.figure(figsize=(10,5))
plt.scatter(sample_df['Time'], sample_df['Amount'], alpha=0.6, c=sample_df['Class'], cmap='coolwarm')
plt.xlabel('Time (seconds)')
plt.ylabel('Amount')
plt.title('Time vs Amount with Class Coloring')
plt.show()

# %%
# This script will help to visualize:

# Class imbalance

# Amount patterns in fraud vs normal transactions

# Feature correlations (e.g. for feature selection later)

# Time-based distribution patterns

# %% [markdown]
# # Adding SMOTE preprocessing

# %%
import numpy as np

# %% [markdown]
# # Set style

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# # Count plot for class

# %%
sns.countplot(x='Class', data=df, hue='Class', palette='Set2', legend=False)
plt.title('Transaction Class Count')
plt.show()

# %% [markdown]
# # Transaction amount distribution

# %%
plt.figure(figsize=(10,6))
sns.histplot(df[df['Class'] == 0]['Amount'], bins=100, color='blue', label='Legit', kde=True)
sns.histplot(df[df['Class'] == 1]['Amount'], bins=100, color='red', label='Fraud', kde=True)
plt.legend()
plt.title('Transaction Amount Distribution')
plt.xlabel('Transaction Amount')
plt.show()

# %% [markdown]
# # Boxplot of Amount by Class

# %%
sns.boxplot(x='Class', y='Amount', hue='Class', data=df, palette='Set3', dodge=False)
plt.title('Transaction Amount by Class')
plt.legend([],[], frameon=False)  # Hides duplicate legend
plt.show()

# %% [markdown]
# # Time distribution of transactions

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Time'], bins=100, color='purple')
plt.title('Transaction Time Distribution (seconds)')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# # Time vs Amount scatter, colored by Class

# %%
sample_df = df.sample(n=10000, random_state=42)
plt.scatter(sample_df['Time'], sample_df['Amount'], c=sample_df['Class'], cmap='coolwarm', alpha=0.6)
plt.title('Time vs. Transaction Amount')
plt.xlabel('Time (seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# # Correlation heatmap

# %%
plt.figure(figsize=(15,12))
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm_r', annot=False, linewidths=0.5)
plt.title('Correlation Heatmap of Features')
plt.show()

# %% [markdown]
# # Top features correlated with fraud

# %%
fraud_corr = corr['Class'].sort_values(ascending=False)
print("\nTop features positively correlated with fraud:\n", fraud_corr.head(10))
print("\nTop features negatively correlated with fraud:\n", fraud_corr.tail(10))
# Out:
# Top features positively correlated with fraud:
#  Class    1.000000
# V11      0.154876
# V4       0.133447
# V2       0.091289
# V21      0.040413
# V19      0.034783
# V20      0.020090
# V8       0.019875
# V27      0.017580
# V28      0.009536
# Name: Class, dtype: float64
#
# Top features negatively correlated with fraud:
#  V9    -0.097733
# V1    -0.101347
# V18   -0.111485
# V7    -0.187257
# V3    -0.192961
# V16   -0.196539
# V10   -0.216883
# V12   -0.260593
# V14   -0.302544
# V17   -0.326481
# Name: Class, dtype: float64

# %% [markdown]
# # Distribution of top correlated features (Example: V17, V14)

# %%
top_features = ['V17', 'V14', 'V12', 'V10']
for feature in top_features:
    plt.figure(figsize=(8,4))
    sns.kdeplot(df[df['Class'] == 0][feature], label='Legit', fill=True)
    sns.kdeplot(df[df['Class'] == 1][feature], label='Fraud', fill=True)
    plt.title(f'Distribution of {feature} by Class')
    plt.legend()
    plt.show()

# %% [markdown]
# # Skewness and Kurtosis of Amount

# %%
print("\nSkewness of Amount:", df['Amount'].skew())
print("Kurtosis of Amount:", df['Amount'].kurt())
# Out:
# Skewness of Amount: 16.977724453761024
# Kurtosis of Amount: 845.0926455465277

# %%
# Interpretation
# The data is heavily imbalanced, with less than 0.2% fraudulent transactions.
# Fraud transactions often show higher values in V17, V14, V12, and V10, useful for feature selection.
# Fraud transaction amounts are typically lower on average but vary more.
# Correlation heatmap reveals strong negative correlation between certain features and fraud.

# %% [markdown]
# # Count the number of fraud and legit transactions

# %%
fraud_counts = df['Class'].value_counts()  # 0 = Legit, 1 = Fraud
labels = ['Legitimate (0)', 'Fraudulent (1)']
colors = ['#66b3ff', '#ff6666']

# %% [markdown]
# # Plot the pie chart

# %%
plt.figure(figsize=(6,6))
plt.pie(fraud_counts, labels=labels, autopct='%1.2f%%', startangle=90, colors=colors, explode=[0, 0.1])
plt.title('Distribution of All Transactions')
plt.axis('equal')  # Ensures pie is circular
plt.show()

# %% [markdown]
# # Overall Class Distribution (Legit vs Fraud)

# %%
fraud_counts = df['Class'].value_counts()
labels = ['Legitimate (0)', 'Fraudulent (1)']
colors = ['#66b3ff', '#ff6666']

plt.figure(figsize=(6,6))
plt.pie(fraud_counts, labels=labels, autopct='%1.2f%%', startangle=90, colors=colors, explode=[0, 0.1])
plt.title('All Transactions: Legit vs Fraud')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Transaction Amount Distribution by Class

# %%
amount_by_class = df.groupby('Class')['Amount'].sum()
labels = ['Legitimate (0)', 'Fraudulent (1)']
colors = ['#99ff99', '#ff9999']

plt.figure(figsize=(6,6))
plt.pie(amount_by_class, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors, explode=[0, 0.1])
plt.title('Total Transaction Amount by Class')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Number of Transactions > Certain Threshold (e.g., Amount > $200) — Fraud vs Legit

# %%
high_value = df[df['Amount'] > 200]
counts = high_value['Class'].value_counts()
labels = ['Legitimate', 'Fraudulent']
colors = ['#aaffc3', '#ffb3ba']

plt.figure(figsize=(6,6))
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors, explode=[0, 0.1])
plt.title('High-Value Transactions (> $200): Fraud vs Legit')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Fraud Distribution by Hour

# %%
import matplotlib.pyplot as plt

# Create 'Hour' column from 'Time'
df['Hour'] = (df['Time'] // 3600) % 24

# Get fraud counts by hour
fraud_by_hour = df[df['Class'] == 1]['Hour'].value_counts().sort_index()

# Prepare data
labels = fraud_by_hour.index.astype(int)
sizes = fraud_by_hour.values

# Optional: define custom colors
colors = plt.cm.Reds(np.linspace(0.4, 1, len(sizes)))

# Plot
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, explode=[0.05]*len(sizes))
plt.title('Fraudulent Transactions by Hour of Day')
plt.axis('equal')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
df = pd.read_csv("creditcard.csv")

# %%
# Dummy test ROC curve (should display no matter what)
y_true = [0, 0, 1, 1]
y_scores = [0.1, 0.4, 0.35, 0.8]

fpr, tpr, _ = roc_curve(y_true, y_scores)
roc_auc = roc_auc_score(y_true, y_scores)

plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('Test ROC Curve')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Prepare real data
X = df.drop('Class', axis=1)
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict probabilities
y_probs = model.predict_proba(X_test)[:, 1]

# Compute ROC
fpr, tpr, _ = roc_curve(y_test, y_probs)
roc_auc = roc_auc_score(y_test, y_probs)

# Plot
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.4f})', color='blue')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Credit Card Fraud Detection')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
df = pd.read_csv("creditcard.csv")

# %%
df.head()

# %%
target_col = 'is_fraud'

# %%
X = df.drop(columns=[target_col])
y = df[target_col]

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# %%
y_probs = model.predict_proba(X_test)[:, 1]

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc

# Load the data
df = pd.read_csv("/mnt/data/7a584ee7-9cb1-4ef8-ab54-203f22d6775d.csv")

# Check your actual target column name
print(df.columns)

# Change this to the actual fraud label column
target_col = 'is_fraud'  # Update if needed

# Clean data
df = df.dropna()

# Define features and target
X = df.drop(columns=[target_col])
y = df[target_col]

# One-hot encode if needed
X = pd.get_dummies(X, drop_first=True)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Fit model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Predict
y_probs = model.predict_proba(X_test)[:, 1]

# Compute ROC
fpr, tpr, _ = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Plot
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})", color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc

# Load data
df = pd.read_csv("creditcard.csv")

# Features and target
X = df.drop(columns=['Class'])
y = df['Class']

# Split data (stratify to preserve class balance)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Train model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Predict probabilities
y_probs = model.predict_proba(X_test)[:, 1]

# ROC Curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Plot
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f"ROC Curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Fraud Detection')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"ROC Curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/ASUS/AppData/Local/Microsoft/WindowsApps/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc

# Load dataset
df = pd.read_csv("creditcard.csv")

# Define features and target
X = df.drop(columns=['Class'])  # features
y = df['Class']                 # target

# Train-test split (stratify for class balance)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Fit logistic regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Predict probabilities
y_probs = model.predict_proba(X_test)[:, 1]

# Calculate ROC curve
fpr, tpr, _ = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"ROC Curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
